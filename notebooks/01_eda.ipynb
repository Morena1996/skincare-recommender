# %%
import kagglehub
import os

# Download the latest version of the Sephora products and skincare reviews dataset
path = kagglehub.dataset_download("nadyinky/sephora-products-and-skincare-reviews")

print("Path to dataset files:", path)

for root, dirs, files in os.walk(path):
    for fname in files:
        print(os.path.join(root, fname))
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/nadyinky/sephora-products-and-skincare-reviews?dataset_version_number=2...
# 100%|██████████| 147M/147M [00:24<00:00, 6.36MB/s]
# Extracting files...
# Path to dataset files: /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/product_info.csv
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/reviews_0-250.csv
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/reviews_1250-end.csv
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/reviews_750-1250.csv
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/reviews_250-500.csv
# /Users/morenabastiaansen/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2/reviews_500-750.csv
